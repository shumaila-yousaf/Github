# %%
import pandas as pd
import numpy as np

# %%
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'

# %%
df = pd.read_csv('D:\\pythonpro\\Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv')

# %%
print(df.head())
# Out:
#      ed Date (Planned) Date (Published)     Month       Day  \
# 0  13.0     21/12/2023      22 Dec 2023  December    Friday
# 1   1.0     21/12/2023      23 Dec 2023  December  Saturday
# 2   2.0     22/12/2023      23 Dec 2023  December  Saturday
# 3   3.0     23/12/2023      23 Dec 2023  December  Saturday
# 4   4.0     25/12/2023      25 Dec 2023  December    Monday
#
#                                                 Name  \
# 0  String.upper()\nString.lower()\nString.title()...
# 1                                                Set
# 2                       Set.union()\nSet.intersect()
# 3                                               List
# 4                                                NaN
#
#                          Title  \
# 0    string function in python
# 1                Set in Python
# 2        Set Methods in Python
# 3               List in Python
# 4  Add formula in google sheet
#
#                                               Detail Examples Status  \
# ...

# %%
df
# Out:
#         ed Date (Planned) Date (Published)     Month       Day  \
# 0     13.0     21/12/2023      22 Dec 2023  December    Friday
# 1      1.0     21/12/2023      23 Dec 2023  December  Saturday
# 2      2.0     22/12/2023      23 Dec 2023  December  Saturday
# 3      3.0     23/12/2023      23 Dec 2023  December  Saturday
# 4      4.0     25/12/2023      25 Dec 2023  December    Monday
# ...    ...            ...              ...       ...       ...
# 1024   NaN            NaN              NaN       NaN       NaN
# 1025   NaN            NaN              NaN       NaN       NaN
# 1026   NaN            NaN              NaN       NaN       NaN
# 1027   NaN            NaN              NaN       NaN       NaN
# 1028   NaN            NaN              NaN       NaN       NaN
#
#                                                    Name  \
# 0     String.upper()\nString.lower()\nString.title()...
# 1                                                   Set
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = {
    'Name': ['Shumaila', 'Mehraj', 'Mehraj', 'Mehraj', 'Mehraj'],
    'Status': ['Done', 'Done', 'Done', 'Done', 'Done']
}
df = pd.DataFrame(data)
plt.figure(figsize=(10, 6))  
sns.countplot(x='Name', hue='Status', data=df)
plt.title('Video Status by Creator')
plt.xlabel('Creator')
plt.ylabel('Count')
plt.show()

# %%
import pandas as pd
data = {
    'Name': ['Shumaila', 'Mehraj', 'Mehraj', 'Mehraj', 'Mehraj'],
    'Status': ['Done', 'Done', 'Done', 'Done', 'Done']
}
df = pd.DataFrame(data)
mehraj_videos = df[df['Name'] == 'Mehraj']
num_mehraj_videos = len(mehraj_videos)
shumaila_videos = df[df['Name'] == 'Shumaila']
num_shumaila_videos = len(shumaila_videos)
print(f"Mehraj made {num_mehraj_videos} videos.")
print(f"Shumaila made {num_shumaila_videos} videos.")
# Out:
# Mehraj made 4 videos.
# Shumaila made 1 videos.

# %%
import pandas as pd
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv('D:\\pythonpro\\Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv')
mehraj_videos = df[df['Creator'] == 'Mehraj']
num_mehraj_videos = len(mehraj_videos)
shumaila_videos = df[df['Creator'] == 'Shumaila']
num_shumaila_videos = len(shumaila_videos)
rimsha_videos = df[df['Creator'] == 'Rimsha']
num_rimsha_videos = len(rimsha_videos)
print(f"Mehraj made {num_mehraj_videos} videos.")
print(f"Shumaila made {num_shumaila_videos} videos.")
print(f"Rimsha made {num_rimsha_videos} videos.")
# Out:
# Mehraj made 187 videos.
# Shumaila made 202 videos.
# Rimsha made 174 videos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv('D:\\pythonpro\\Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv')
mehraj_videos = df[df['Creator'] == 'Mehraj']
num_mehraj_videos = len(mehraj_videos)
shumaila_videos = df[df['Creator'] == 'Shumaila']
num_shumaila_videos = len(shumaila_videos)
rimsha_videos = df[df['Creator'] == 'Rimsha']
num_rimsha_videos = len(rimsha_videos)
creators = ['Mehraj', 'Shumaila', 'Rimsha']
video_counts = [num_mehraj_videos, num_shumaila_videos, num_rimsha_videos]
plt.figure(figsize=(10, 6))
plt.bar(creators, video_counts, color=['pink', 'red', 'yellow'])
plt.xlabel('Creator')
plt.ylabel('Number of Videos')
plt.title('Number of Videos by Creator')
plt.show()

# %%
import pandas as pd
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv('D:\\pythonpro\\Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv')
mehraj_df = df[df['Creator'] == 'Mehraj']
shumaila_df = df[df['Creator'] == 'Shumaila']
rimsha_df = df[df['Creator'] == 'Rimsha']
total_time_mehraj = mehraj_df['Time (in minutes)'].sum()
total_time_shumaila = shumaila_df['Time (in minutes)'].sum()
total_time_rimsha = rimsha_df['Time (in minutes)'].sum()
print(f"Total time worked by Mehraj: {total_time_mehraj} minutes")
print(f"Total time worked by Shumaila: {total_time_shumaila} minutes")
print(f"Total time worked by Rimsha: {total_time_rimsha} minutes")
# Out:
# Total time worked by Mehraj: 1941.0 minutes
# Total time worked by Shumaila: 2450.0 minutes
# Total time worked by Rimsha: 1984.0 minutes

# %%
import pandas as pd
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv('D:\\pythonpro\\Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv')
df['Time (in hours)'] = df['Time (in minutes)'] / 60
total_time_by_creator = df.groupby('Creator')['Time (in hours)'].sum()
print("Total time worked (hours) by each creator:")
print(total_time_by_creator)
# Out:
# Total time worked (hours) by each creator:
# Creator
# Mehraj      32.350000
# Rimsha      33.066667
# Shumaila    40.833333
# Name: Time (in hours), dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv(file_path)
total_time_by_creator = df.groupby('Creator')['Time (in minutes)'].sum()
plt.figure(figsize=(10, 6))  
total_time_by_creator.plot(kind='bar', color=['blue', 'green', 'orange'])
plt.title('Total Time Worked by Creator')
plt.xlabel('Creator')
plt.ylabel('Total Time (minutes)')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Daily Upload for Creator:

# %%
import pandas as pd
import numpy as np

# %%
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'

# %%
df = pd.read_csv('D:\\pythonpro\\Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv')

# %%
df
# Out:
#         ed Date (Planned) Date (Published)     Month       Day  \
# 0     13.0     21/12/2023      22 Dec 2023  December    Friday
# 1      1.0     21/12/2023      23 Dec 2023  December  Saturday
# 2      2.0     22/12/2023      23 Dec 2023  December  Saturday
# 3      3.0     23/12/2023      23 Dec 2023  December  Saturday
# 4      4.0     25/12/2023      25 Dec 2023  December    Monday
# ...    ...            ...              ...       ...       ...
# 1024   NaN            NaN              NaN       NaN       NaN
# 1025   NaN            NaN              NaN       NaN       NaN
# 1026   NaN            NaN              NaN       NaN       NaN
# 1027   NaN            NaN              NaN       NaN       NaN
# 1028   NaN            NaN              NaN       NaN       NaN
#
#                                                    Name  \
# 0     String.upper()\nString.lower()\nString.title()...
# 1                                                   Set
# ...

# %%
import pandas as pd
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv(file_path)
df['Date (Published)'] = pd.to_datetime(df['Date (Published)'], dayfirst=True, format='%d %b %Y', errors='coerce')
problematic_rows = df[pd.isna(df['Date (Published)'])]
print("Problematic rows after date conversion:")
print(problematic_rows)
daily_upload_count = df.groupby(['Creator', df['Date (Published)'].dt.date]).size()
print("\nDaily Uploads by Creator:")
print(daily_upload_count)
# Out:
# Problematic rows after date conversion:
#          ed Date (Planned) Date (Published)     Month        Day  \
# 334     9.0            NaN              NaT       NaN        NaN
# 338   176.0            NaN              NaT       NaN        NaN
# 340   319.0    27 Feb 2024              NaT  February    Tuesday
# 519   498.0    13-Mar-2024              NaT     March  Wednesday
# 526   505.0    14-Mar-2024              NaT     March   Thursday
# ...     ...            ...              ...       ...        ...
# 1024    NaN            NaN              NaT       NaN        NaN
# 1025    NaN            NaN              NaT       NaN        NaN
# 1026    NaN            NaN              NaT       NaN        NaN
# 1027    NaN            NaN              NaT       NaN        NaN
# 1028    NaN            NaN              NaT       NaN        NaN
#
#                                            Name  \
# 334                                  Dictionary
# ...

# %% [markdown]
# # Bar chart (Daily uploads by creator)

# %% [markdown]
# # Pie chart (Daily uploads by creator)

# %%
import matplotlib.pyplot as plt
daily_upload_count = df.groupby(['Creator', df['Date (Published)'].dt.date]).size()
plt.figure(figsize=(8, 8)) 
colors = ['gold', 'lightcoral', 'lightskyblue']  
daily_upload_count.groupby('Creator').sum().plot.pie(autopct='%1.1f%%', colors=colors)
plt.title('Daily Uploads Distribution by Creator')
plt.ylabel('')  
plt.legend(title='Creator', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Monthly upload by creator

# %%
import pandas as pd
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv(file_path)
df['Date (Published)'] = pd.to_datetime(df['Date (Published)'], dayfirst=True, errors='coerce')
df = df.dropna(subset=['Date (Published)'])
monthly_upload_count = df.groupby(['Creator', df['Date (Published)'].dt.month]).size()
print("Monthly Uploads by Creator:")
print(monthly_upload_count)
# Out:
# Monthly Uploads by Creator:
# Creator   Date (Published)
# Mehraj    1                   55
#           2                   52
#           3                   69
#           12                   9
# Rimsha    1                   47
#           2                   66
#           3                   55
#           12                   6
# Shumaila  1                   41
#           2                   83
#           3                   64
#           12                   9
# dtype: int64

# %% [markdown]
# # clearly explain

# %%
import pandas as pd
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv(file_path)
df['Date (Published)'] = pd.to_datetime(df['Date (Published)'], dayfirst=True, errors='coerce')
df = df.dropna(subset=['Date (Published)'])
df['Month'] = df['Date (Published)'].dt.month
df['Year'] = df['Date (Published)'].dt.year
monthly_upload_count = df.groupby(['Creator', 'Year', 'Month']).size()
monthly_upload_count = monthly_upload_count.reset_index(name='Upload Count')
print("Monthly Uploads by Creator:")
print(monthly_upload_count)
# Out:
# Monthly Uploads by Creator:
#      Creator  Year  Month  Upload Count
# 0     Mehraj  2023     12             9
# 1     Mehraj  2024      1            55
# 2     Mehraj  2024      2            52
# 3     Mehraj  2024      3            69
# 4     Rimsha  2023     12             6
# 5     Rimsha  2024      1            47
# 6     Rimsha  2024      2            66
# 7     Rimsha  2024      3            55
# 8   Shumaila  2023     12             9
# 9   Shumaila  2024      1            41
# 10  Shumaila  2024      2            83
# 11  Shumaila  2024      3            64

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv(file_path)
df['Date (Published)'] = pd.to_datetime(df['Date (Published)'], dayfirst=True, errors='coerce')
df = df.dropna(subset=['Date (Published)'])
df['Month'] = df['Date (Published)'].dt.month
df['Year'] = df['Date (Published)'].dt.year
monthly_upload_count = df.groupby(['Creator', 'Year', 'Month']).size().unstack(level=0)
monthly_upload_count.plot(kind='bar', figsize=(10, 6))
plt.title('Monthly Uploads by Creator')
plt.xlabel('Month')
plt.ylabel('Upload Count')
plt.xticks(rotation=0)
plt.legend(title='Creator')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Total time by creator

# %%
import pandas as pd
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv(file_path)
total_time_by_creator = df.groupby('Creator')['Time (in minutes)'].sum()
print("Total Time by Creator:")
print(total_time_by_creator)
# Out:
# Total Time by Creator:
# Creator
# Mehraj      1941.0
# Rimsha      1984.0
# Shumaila    2450.0
# Name: Time (in minutes), dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv(file_path)
total_time_by_creator = df.groupby('Creator')['Time (in minutes)'].sum()
plt.figure(figsize=(10, 6))
total_time_by_creator.plot(kind='bar', color='skyblue')
plt.title('Total Time by Creator')
plt.xlabel('Creator')
plt.ylabel('Total Time (minutes)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Total time

# %%
import pandas as pd
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv(file_path)
total_time_combined = df['Time (in minutes)'].sum()
print("Total Time of All Creators Combined:", total_time_combined, "minutes")
# Out:
# Total Time of All Creators Combined: 6375.0 minutes

# %% [markdown]
# #  Monthly uploaded videos by Mehraj

# %%
import pandas as pd
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv(file_path)
df['Date (Published)'] = pd.to_datetime(df['Date (Published)'], dayfirst=True, errors='coerce')
mehraj_data = df[df['Creator'] == 'Mehraj']
mehraj_monthly_count = mehraj_data['Date (Published)'].dt.to_period('M').value_counts().sort_index()
month_order = ['2023-12', '2024-01', '2024-02', '2024-03']
mehraj_monthly_count = mehraj_monthly_count.reindex(month_order, fill_value=0)
print(mehraj_monthly_count)
# Out:
# Date (Published)
# 2023-12     9
# 2024-01    55
# 2024-02    52
# 2024-03    69
# Name: count, dtype: int64

# %% [markdown]
# # Graph of Mehraj

# %%
import pandas as pd
import matplotlib.pyplot as plt
mehraj_monthly_count = pd.Series({
    '2023-12': 10,
    '2024-01': 15,
    '2024-02': 12,
    '2024-03': 20
})
plt.figure(figsize=(10, 6))
mehraj_monthly_count.plot(kind='bar', color='skyblue')
plt.title('Monthly Uploads by Mehraj')
plt.xlabel('Month')
plt.ylabel('Number of Uploads')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Monthly uploaded videos by Rimsha

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv(file_path)
df['Date (Published)'] = pd.to_datetime(df['Date (Published)'], dayfirst=True, errors='coerce')
rimsha_data = df[df['Creator'] == 'Rimsha']
rimsha_monthly_count = rimsha_data['Date (Published)'].dt.to_period('M').value_counts().sort_index()
month_order = ['2023-12', '2024-01', '2024-02', '2024-03']
rimsha_monthly_count = rimsha_monthly_count.reindex(month_order, fill_value=0)
print(rimsha_monthly_count)
plt.figure(figsize=(10, 6))
rimsha_monthly_count.plot(kind='bar', color='lightgreen')
plt.title('Monthly Uploads by Rimsha')
plt.xlabel('Month')
plt.ylabel('Number of Uploads')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# Date (Published)
# 2023-12     6
# 2024-01    47
# 2024-02    66
# 2024-03    55
# Name: count, dtype: int64

# %% [markdown]
# # Monthly uploaded videos by shumaila

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path = r'D:/pythonpro/Python Videos for Python Pro Channel (Morning) - Pytho Pro.csv'
df = pd.read_csv(file_path)
df['Date (Published)'] = pd.to_datetime(df['Date (Published)'], dayfirst=True, errors='coerce')
shumaila_data = df[df['Creator'] == 'Shumaila']
shumaila_monthly_count = shumaila_data['Date (Published)'].dt.to_period('M').value_counts().sort_index()
month_order = ['2023-12', '2024-01', '2024-02', '2024-03']
shumaila_monthly_count = shumaila_monthly_count.reindex(month_order, fill_value=0)
print(shumaila_monthly_count)
plt.figure(figsize=(10, 6))
shumaila_monthly_count.plot(kind='bar', color='green')
plt.title('Monthly Uploads by Shumaila')
plt.xlabel('Month')
plt.ylabel('Number of Uploads')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# Date (Published)
# 2023-12     9
# 2024-01    41
# 2024-02    83
# 2024-03    64
# Name: count, dtype: int64
